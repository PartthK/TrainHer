# %%
import cv2
import mediapipe as mp
import pyttsx3
import numpy as np
from sklearn.metrics import mean_squared_error
import random

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_drawing = mp.solutions.drawing_utils

# Text-to-Speech Engine
engine = pyttsx3.init()

# Function to extract pose landmarks from an image
def extract_pose_from_image(image_path):
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Could not read the image {image_path}.")
        return None

    # Convert to RGB
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Process the image with MediaPipe Pose
    results = pose.process(rgb_image)

    # Extract pose landmarks
    if results.pose_landmarks:
        keypoints = [
            (landmark.x, landmark.y) for landmark in results.pose_landmarks.landmark
        ]
        return np.array(keypoints)
    else:
        print(f"No pose detected in the image {image_path}.")
        return None

# Function to calculate accuracy percentage from MSE
def calculate_accuracy(mse, max_mse):
    # Ensure accuracy is within the range [0, 100]
    accuracy = max(0, 100 * (1 - (mse / max_mse)))
    return accuracy

# Function to analyze moves using the webcam
def analyze_moves(reference_poses):
    cap = cv2.VideoCapture(0)
    print("Camera activated. Waiting for your moves...")

    # Randomly select a move
    move_names = list(reference_poses.keys())
    selected_move = random.choice(move_names)
    print(f"Perform the move: {selected_move.upper()}")
    engine.say(f"Perform the move: {selected_move}")
    engine.runAndWait()

    # Define a maximum MSE value for normalization
    max_mse = 0.1  # Adjust this based on your application

    while True:
        ret, frame = cap.read()
        if not ret:
            print("Failed to capture frame. Exiting...")
            break

        # Flip frame for a mirror-like experience
        frame = cv2.flip(frame, 1)

        # Convert frame to RGB
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process with MediaPipe Pose
        results = pose.process(rgb_frame)

        # Draw pose landmarks
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

            # Extract keypoints
            keypoints = [
                (landmark.x, landmark.y) for landmark in results.pose_landmarks.landmark
            ]

            # Convert to numpy array
            user_pose = np.array(keypoints)

            # Calculate Mean Squared Error
            reference_pose = reference_poses[selected_move]
            mse = mean_squared_error(reference_pose.flatten(), user_pose.flatten()[:len(reference_pose.flatten())])

            # Calculate accuracy percentage
            accuracy = calculate_accuracy(mse, max_mse)

            if accuracy > 80:  # Example threshold for "good" accuracy
                feedback = f"Great job! Your {selected_move} move accuracy is {accuracy:.2f}%."
            else:
                feedback = f"Keep practicing! Your {selected_move} move accuracy is {accuracy:.2f}%."

            # Display feedback on screen
            cv2.putText(frame, feedback, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            print(feedback)

        # Show the frame
        cv2.imshow("Self-Defense Trainer", frame)

        # Break on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# Main Function
if __name__ == "__main__":
    # Load reference poses for "punch", "kick", "upper block", "middle block", and "downward block"
    reference_images = {
        "punch": "punch_pose.jpg",                  # Replace with the path to the punch image
        "kick": "kick_pose.jpg",                    # Replace with the path to the kick image
        "upper block": "upper_block_pose.jpg",      # Replace with the path to the upper block image
        "middle block": "middle_block_pose.jpg",    # Replace with the path to the middle block image
        "downward block": "downward_block_pose.webp" # Replace with the path to the downward block image
    }

    reference_poses = {}
    for move, image_path in reference_images.items():
        reference_pose = extract_pose_from_image(image_path)
        if reference_pose is not None:
            reference_poses[move] = reference_pose
        else:
            print(f"Failed to load pose for {move}. Exiting.")
            exit(1)

    analyze_moves(reference_poses)
# Out:
# I0000 00:00:1737842451.375738 67959697 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 88.1), renderer: Apple M2
# W0000 00:00:1737842451.521176 67964509 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737842451.547169 67964511 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Error: Could not read the image middle_block_pose.jpg.
# Failed to load pose for middle block. Exiting.
# Camera activated. Waiting for your moves...
# Perform the move: DOWNWARD BLOCK
# [ WARN:0@198.496] global loadsave.cpp:268 findDecoder imread_('middle_block_pose.jpg'): can't open/read file: check file path/integrity
# Keep practicing! Your downward block move accuracy is 35.85%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 1.58%.
# Keep practicing! Your downward block move accuracy is 2.14%.
# Keep practicing! Your downward block move accuracy is 3.32%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 36.14%.
# Keep practicing! Your downward block move accuracy is 42.08%.
# Keep practicing! Your downward block move accuracy is 32.59%.
# Keep practicing! Your downward block move accuracy is 23.77%.
# Keep practicing! Your downward block move accuracy is 8.21%.
# Keep practicing! Your downward block move accuracy is 1.02%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 4.52%.
# Keep practicing! Your downward block move accuracy is 8.92%.
# Keep practicing! Your downward block move accuracy is 14.97%.
# Keep practicing! Your downward block move accuracy is 19.69%.
# Keep practicing! Your downward block move accuracy is 22.02%.
# Keep practicing! Your downward block move accuracy is 22.67%.
# Keep practicing! Your downward block move accuracy is 22.89%.
# Keep practicing! Your downward block move accuracy is 21.28%.
# Keep practicing! Your downward block move accuracy is 16.69%.
# Keep practicing! Your downward block move accuracy is 14.42%.
# Keep practicing! Your downward block move accuracy is 13.48%.
# Keep practicing! Your downward block move accuracy is 10.13%.
# Keep practicing! Your downward block move accuracy is 14.86%.
# Keep practicing! Your downward block move accuracy is 19.91%.
# Keep practicing! Your downward block move accuracy is 24.09%.
# Keep practicing! Your downward block move accuracy is 29.85%.
# Keep practicing! Your downward block move accuracy is 35.41%.
# Keep practicing! Your downward block move accuracy is 38.12%.
# Keep practicing! Your downward block move accuracy is 41.03%.
# Keep practicing! Your downward block move accuracy is 42.31%.
# Keep practicing! Your downward block move accuracy is 44.10%.
# Keep practicing! Your downward block move accuracy is 46.53%.
# Keep practicing! Your downward block move accuracy is 51.16%.
# Keep practicing! Your downward block move accuracy is 59.58%.
# Keep practicing! Your downward block move accuracy is 66.64%.
# Keep practicing! Your downward block move accuracy is 66.82%.
# Keep practicing! Your downward block move accuracy is 67.28%.
# Keep practicing! Your downward block move accuracy is 66.54%.
# Keep practicing! Your downward block move accuracy is 66.42%.
# Keep practicing! Your downward block move accuracy is 66.68%.
# Keep practicing! Your downward block move accuracy is 66.03%.
# Keep practicing! Your downward block move accuracy is 67.08%.
# Keep practicing! Your downward block move accuracy is 66.05%.
# Keep practicing! Your downward block move accuracy is 66.91%.
# Keep practicing! Your downward block move accuracy is 66.60%.
# Keep practicing! Your downward block move accuracy is 64.60%.
# Keep practicing! Your downward block move accuracy is 63.88%.
# Keep practicing! Your downward block move accuracy is 63.50%.
# Keep practicing! Your downward block move accuracy is 62.66%.
# Keep practicing! Your downward block move accuracy is 62.85%.
# Keep practicing! Your downward block move accuracy is 63.07%.
# Keep practicing! Your downward block move accuracy is 64.50%.
# Keep practicing! Your downward block move accuracy is 64.18%.
# Keep practicing! Your downward block move accuracy is 63.98%.
# Keep practicing! Your downward block move accuracy is 63.49%.
# Keep practicing! Your downward block move accuracy is 63.02%.
# Keep practicing! Your downward block move accuracy is 63.47%.
# Keep practicing! Your downward block move accuracy is 64.15%.
# Keep practicing! Your downward block move accuracy is 65.72%.
# Keep practicing! Your downward block move accuracy is 66.72%.
# Keep practicing! Your downward block move accuracy is 67.85%.
# Keep practicing! Your downward block move accuracy is 68.03%.
# Keep practicing! Your downward block move accuracy is 68.08%.
# Keep practicing! Your downward block move accuracy is 68.61%.
# Keep practicing! Your downward block move accuracy is 68.89%.
# Keep practicing! Your downward block move accuracy is 68.45%.
# Keep practicing! Your downward block move accuracy is 68.88%.
# Keep practicing! Your downward block move accuracy is 68.97%.
# Keep practicing! Your downward block move accuracy is 69.16%.
# Keep practicing! Your downward block move accuracy is 69.55%.
# Keep practicing! Your downward block move accuracy is 70.18%.
# Keep practicing! Your downward block move accuracy is 71.69%.
# Keep practicing! Your downward block move accuracy is 73.34%.
# Keep practicing! Your downward block move accuracy is 73.95%.
# Keep practicing! Your downward block move accuracy is 73.94%.
# Keep practicing! Your downward block move accuracy is 73.11%.
# Keep practicing! Your downward block move accuracy is 72.43%.
# Keep practicing! Your downward block move accuracy is 71.56%.
# Keep practicing! Your downward block move accuracy is 70.39%.
# Keep practicing! Your downward block move accuracy is 69.47%.
# Keep practicing! Your downward block move accuracy is 68.24%.
# Keep practicing! Your downward block move accuracy is 67.30%.
# Keep practicing! Your downward block move accuracy is 67.37%.
# Keep practicing! Your downward block move accuracy is 67.72%.
# Keep practicing! Your downward block move accuracy is 67.50%.
# Keep practicing! Your downward block move accuracy is 67.56%.
# Keep practicing! Your downward block move accuracy is 67.57%.
# Keep practicing! Your downward block move accuracy is 67.77%.
# Keep practicing! Your downward block move accuracy is 67.79%.
# Keep practicing! Your downward block move accuracy is 68.02%.
# Keep practicing! Your downward block move accuracy is 68.41%.
# Keep practicing! Your downward block move accuracy is 68.93%.
# Keep practicing! Your downward block move accuracy is 69.43%.
# Keep practicing! Your downward block move accuracy is 69.83%.
# Keep practicing! Your downward block move accuracy is 70.57%.
# Keep practicing! Your downward block move accuracy is 72.87%.
# Keep practicing! Your downward block move accuracy is 77.68%.
# Great job! Your downward block move accuracy is 80.21%.
# Great job! Your downward block move accuracy is 80.07%.
# Keep practicing! Your downward block move accuracy is 76.71%.
# Keep practicing! Your downward block move accuracy is 75.73%.
# Keep practicing! Your downward block move accuracy is 74.97%.
# Keep practicing! Your downward block move accuracy is 74.68%.
# Keep practicing! Your downward block move accuracy is 74.30%.
# Keep practicing! Your downward block move accuracy is 74.33%.
# Keep practicing! Your downward block move accuracy is 74.18%.
# Keep practicing! Your downward block move accuracy is 73.82%.
# Keep practicing! Your downward block move accuracy is 73.29%.
# Keep practicing! Your downward block move accuracy is 73.00%.
# Keep practicing! Your downward block move accuracy is 72.43%.
# Keep practicing! Your downward block move accuracy is 71.64%.
# Keep practicing! Your downward block move accuracy is 70.83%.
# Keep practicing! Your downward block move accuracy is 70.10%.
# Keep practicing! Your downward block move accuracy is 69.07%.
# Keep practicing! Your downward block move accuracy is 68.20%.
# Keep practicing! Your downward block move accuracy is 67.92%.
# Keep practicing! Your downward block move accuracy is 67.67%.
# Keep practicing! Your downward block move accuracy is 66.98%.
# Keep practicing! Your downward block move accuracy is 66.18%.
# Keep practicing! Your downward block move accuracy is 66.22%.
# Keep practicing! Your downward block move accuracy is 66.59%.
# Keep practicing! Your downward block move accuracy is 65.21%.
# Keep practicing! Your downward block move accuracy is 64.04%.
# Keep practicing! Your downward block move accuracy is 63.00%.
# Keep practicing! Your downward block move accuracy is 61.93%.
# Keep practicing! Your downward block move accuracy is 61.75%.
# Keep practicing! Your downward block move accuracy is 62.02%.
# Keep practicing! Your downward block move accuracy is 62.80%.
# Keep practicing! Your downward block move accuracy is 62.64%.
# Keep practicing! Your downward block move accuracy is 62.89%.
# Keep practicing! Your downward block move accuracy is 63.84%.
# Keep practicing! Your downward block move accuracy is 64.47%.
# Keep practicing! Your downward block move accuracy is 65.09%.
# Keep practicing! Your downward block move accuracy is 65.52%.
# Keep practicing! Your downward block move accuracy is 65.78%.
# Keep practicing! Your downward block move accuracy is 65.91%.
# Keep practicing! Your downward block move accuracy is 65.12%.
# Keep practicing! Your downward block move accuracy is 65.41%.
# Keep practicing! Your downward block move accuracy is 67.70%.
# Keep practicing! Your downward block move accuracy is 67.17%.
# Keep practicing! Your downward block move accuracy is 64.28%.
# Keep practicing! Your downward block move accuracy is 62.78%.
# Keep practicing! Your downward block move accuracy is 62.80%.
# Keep practicing! Your downward block move accuracy is 62.93%.
# Keep practicing! Your downward block move accuracy is 62.84%.
# Keep practicing! Your downward block move accuracy is 63.07%.
# Keep practicing! Your downward block move accuracy is 63.42%.
# Keep practicing! Your downward block move accuracy is 62.03%.
# Keep practicing! Your downward block move accuracy is 61.57%.
# Keep practicing! Your downward block move accuracy is 61.79%.
# Keep practicing! Your downward block move accuracy is 61.71%.
# Keep practicing! Your downward block move accuracy is 61.84%.
# Keep practicing! Your downward block move accuracy is 61.59%.
# Keep practicing! Your downward block move accuracy is 61.44%.
# Keep practicing! Your downward block move accuracy is 62.02%.
# Keep practicing! Your downward block move accuracy is 62.57%.
# Keep practicing! Your downward block move accuracy is 63.86%.
# Keep practicing! Your downward block move accuracy is 63.37%.
# Keep practicing! Your downward block move accuracy is 58.82%.
# Keep practicing! Your downward block move accuracy is 54.22%.
# Keep practicing! Your downward block move accuracy is 55.68%.
# Keep practicing! Your downward block move accuracy is 56.53%.
# Keep practicing! Your downward block move accuracy is 60.10%.
# Keep practicing! Your downward block move accuracy is 62.06%.
# Keep practicing! Your downward block move accuracy is 64.13%.
# Keep practicing! Your downward block move accuracy is 65.17%.
# Keep practicing! Your downward block move accuracy is 64.76%.
# Keep practicing! Your downward block move accuracy is 62.69%.
# Keep practicing! Your downward block move accuracy is 60.32%.
# Keep practicing! Your downward block move accuracy is 60.73%.
# Keep practicing! Your downward block move accuracy is 61.43%.
# Keep practicing! Your downward block move accuracy is 61.06%.
# Keep practicing! Your downward block move accuracy is 58.69%.
# Keep practicing! Your downward block move accuracy is 57.19%.
# Keep practicing! Your downward block move accuracy is 57.75%.
# Keep practicing! Your downward block move accuracy is 59.72%.
# Keep practicing! Your downward block move accuracy is 60.21%.
# Keep practicing! Your downward block move accuracy is 60.61%.
# Keep practicing! Your downward block move accuracy is 61.53%.
# Keep practicing! Your downward block move accuracy is 61.85%.
# Keep practicing! Your downward block move accuracy is 61.43%.
# Keep practicing! Your downward block move accuracy is 60.18%.
# Keep practicing! Your downward block move accuracy is 59.61%.
# Keep practicing! Your downward block move accuracy is 59.92%.
# Keep practicing! Your downward block move accuracy is 60.06%.
# Keep practicing! Your downward block move accuracy is 59.78%.
# Keep practicing! Your downward block move accuracy is 59.39%.
# Keep practicing! Your downward block move accuracy is 59.23%.
# Keep practicing! Your downward block move accuracy is 59.90%.
# Keep practicing! Your downward block move accuracy is 61.15%.
# Keep practicing! Your downward block move accuracy is 62.77%.
# Keep practicing! Your downward block move accuracy is 64.00%.
# Keep practicing! Your downward block move accuracy is 64.06%.
# Keep practicing! Your downward block move accuracy is 64.13%.
# Keep practicing! Your downward block move accuracy is 64.10%.
# Keep practicing! Your downward block move accuracy is 63.93%.
# Keep practicing! Your downward block move accuracy is 63.82%.
# Keep practicing! Your downward block move accuracy is 64.49%.
# Keep practicing! Your downward block move accuracy is 64.62%.
# Keep practicing! Your downward block move accuracy is 64.84%.
# Keep practicing! Your downward block move accuracy is 65.35%.
# Keep practicing! Your downward block move accuracy is 65.55%.
# Keep practicing! Your downward block move accuracy is 65.58%.
# Keep practicing! Your downward block move accuracy is 65.66%.
# Keep practicing! Your downward block move accuracy is 65.60%.
# Keep practicing! Your downward block move accuracy is 65.45%.
# Keep practicing! Your downward block move accuracy is 65.83%.
# Keep practicing! Your downward block move accuracy is 65.85%.
# Keep practicing! Your downward block move accuracy is 65.82%.
# Keep practicing! Your downward block move accuracy is 65.94%.
# Keep practicing! Your downward block move accuracy is 66.22%.
# Keep practicing! Your downward block move accuracy is 66.34%.
# Keep practicing! Your downward block move accuracy is 66.40%.
# Keep practicing! Your downward block move accuracy is 66.42%.
# Keep practicing! Your downward block move accuracy is 66.33%.
# Keep practicing! Your downward block move accuracy is 66.08%.
# Keep practicing! Your downward block move accuracy is 66.05%.
# Keep practicing! Your downward block move accuracy is 66.05%.
# Keep practicing! Your downward block move accuracy is 66.50%.
# Keep practicing! Your downward block move accuracy is 66.56%.
# Keep practicing! Your downward block move accuracy is 66.20%.
# Keep practicing! Your downward block move accuracy is 65.94%.
# Keep practicing! Your downward block move accuracy is 65.98%.
# Keep practicing! Your downward block move accuracy is 66.00%.
# Keep practicing! Your downward block move accuracy is 65.83%.
# Keep practicing! Your downward block move accuracy is 65.73%.
# Keep practicing! Your downward block move accuracy is 65.50%.
# Keep practicing! Your downward block move accuracy is 65.33%.
# Keep practicing! Your downward block move accuracy is 65.14%.
# Keep practicing! Your downward block move accuracy is 65.32%.
# Keep practicing! Your downward block move accuracy is 66.87%.
# Keep practicing! Your downward block move accuracy is 64.92%.
# Keep practicing! Your downward block move accuracy is 62.33%.
# Keep practicing! Your downward block move accuracy is 62.58%.
# Keep practicing! Your downward block move accuracy is 62.75%.
# Keep practicing! Your downward block move accuracy is 62.95%.
# Keep practicing! Your downward block move accuracy is 63.19%.
# Keep practicing! Your downward block move accuracy is 63.49%.
# Keep practicing! Your downward block move accuracy is 63.73%.
# Keep practicing! Your downward block move accuracy is 65.03%.
# Keep practicing! Your downward block move accuracy is 65.57%.
# Keep practicing! Your downward block move accuracy is 65.67%.
# Keep practicing! Your downward block move accuracy is 65.66%.
# Keep practicing! Your downward block move accuracy is 65.66%.
# Keep practicing! Your downward block move accuracy is 65.82%.
# Keep practicing! Your downward block move accuracy is 66.93%.
# Keep practicing! Your downward block move accuracy is 67.16%.
# Keep practicing! Your downward block move accuracy is 67.08%.
# Keep practicing! Your downward block move accuracy is 67.09%.
# Keep practicing! Your downward block move accuracy is 66.57%.
# Keep practicing! Your downward block move accuracy is 64.53%.
# Keep practicing! Your downward block move accuracy is 60.94%.
# Keep practicing! Your downward block move accuracy is 59.79%.
# Keep practicing! Your downward block move accuracy is 59.27%.
# Keep practicing! Your downward block move accuracy is 58.44%.
# Keep practicing! Your downward block move accuracy is 57.30%.
# Keep practicing! Your downward block move accuracy is 58.78%.
# Keep practicing! Your downward block move accuracy is 61.13%.
# Keep practicing! Your downward block move accuracy is 62.42%.
# Keep practicing! Your downward block move accuracy is 61.69%.
# Keep practicing! Your downward block move accuracy is 59.63%.
# Keep practicing! Your downward block move accuracy is 58.85%.
# Keep practicing! Your downward block move accuracy is 59.23%.
# Keep practicing! Your downward block move accuracy is 59.92%.
# Keep practicing! Your downward block move accuracy is 60.20%.
# Keep practicing! Your downward block move accuracy is 61.44%.
# Keep practicing! Your downward block move accuracy is 62.61%.
# Keep practicing! Your downward block move accuracy is 62.98%.
# Keep practicing! Your downward block move accuracy is 63.29%.
# Keep practicing! Your downward block move accuracy is 63.60%.
# Keep practicing! Your downward block move accuracy is 63.53%.
# Keep practicing! Your downward block move accuracy is 63.49%.
# Keep practicing! Your downward block move accuracy is 63.37%.
# Keep practicing! Your downward block move accuracy is 63.74%.
# Keep practicing! Your downward block move accuracy is 64.82%.
# Keep practicing! Your downward block move accuracy is 65.07%.
# Keep practicing! Your downward block move accuracy is 66.02%.
# Keep practicing! Your downward block move accuracy is 67.09%.
# Keep practicing! Your downward block move accuracy is 68.49%.
# Keep practicing! Your downward block move accuracy is 70.17%.
# Keep practicing! Your downward block move accuracy is 70.70%.
# Keep practicing! Your downward block move accuracy is 70.25%.
# Keep practicing! Your downward block move accuracy is 70.04%.
# Keep practicing! Your downward block move accuracy is 67.81%.
# Keep practicing! Your downward block move accuracy is 61.84%.
# Keep practicing! Your downward block move accuracy is 53.82%.
# Keep practicing! Your downward block move accuracy is 52.32%.
# Keep practicing! Your downward block move accuracy is 53.18%.
# Keep practicing! Your downward block move accuracy is 55.53%.
# Keep practicing! Your downward block move accuracy is 59.74%.
# Keep practicing! Your downward block move accuracy is 67.06%.
# Keep practicing! Your downward block move accuracy is 73.09%.
# Keep practicing! Your downward block move accuracy is 77.34%.
# Great job! Your downward block move accuracy is 80.37%.
# Great job! Your downward block move accuracy is 82.59%.
# Great job! Your downward block move accuracy is 84.33%.
# Great job! Your downward block move accuracy is 86.59%.
# Great job! Your downward block move accuracy is 88.50%.
# Great job! Your downward block move accuracy is 89.49%.
# Great job! Your downward block move accuracy is 89.96%.
# Great job! Your downward block move accuracy is 90.26%.
# Great job! Your downward block move accuracy is 90.05%.
# Great job! Your downward block move accuracy is 90.07%.
# Great job! Your downward block move accuracy is 89.72%.
# Great job! Your downward block move accuracy is 89.80%.
# Great job! Your downward block move accuracy is 89.76%.
# Great job! Your downward block move accuracy is 89.22%.
# Great job! Your downward block move accuracy is 88.28%.
# Great job! Your downward block move accuracy is 87.67%.
# Great job! Your downward block move accuracy is 87.41%.
# Great job! Your downward block move accuracy is 87.20%.
# Great job! Your downward block move accuracy is 86.90%.
# Great job! Your downward block move accuracy is 86.66%.
# Great job! Your downward block move accuracy is 86.61%.
# Great job! Your downward block move accuracy is 86.60%.
# Great job! Your downward block move accuracy is 86.51%.
# Great job! Your downward block move accuracy is 86.70%.
# Great job! Your downward block move accuracy is 86.83%.
# Great job! Your downward block move accuracy is 87.23%.
# Great job! Your downward block move accuracy is 87.83%.
# Great job! Your downward block move accuracy is 88.34%.
# Great job! Your downward block move accuracy is 88.56%.
# Great job! Your downward block move accuracy is 88.61%.
# Great job! Your downward block move accuracy is 88.62%.
# Great job! Your downward block move accuracy is 88.76%.
# Great job! Your downward block move accuracy is 88.75%.
# Great job! Your downward block move accuracy is 88.87%.
# Great job! Your downward block move accuracy is 89.01%.
# Great job! Your downward block move accuracy is 89.21%.
# Great job! Your downward block move accuracy is 89.39%.
# Great job! Your downward block move accuracy is 89.46%.
# Great job! Your downward block move accuracy is 89.45%.
# Great job! Your downward block move accuracy is 89.48%.
# Great job! Your downward block move accuracy is 89.58%.
# Great job! Your downward block move accuracy is 89.62%.
# Great job! Your downward block move accuracy is 89.71%.
# Great job! Your downward block move accuracy is 89.76%.
# Great job! Your downward block move accuracy is 89.86%.
# Great job! Your downward block move accuracy is 89.83%.
# Great job! Your downward block move accuracy is 89.57%.
# Great job! Your downward block move accuracy is 89.16%.
# Great job! Your downward block move accuracy is 88.76%.
# Great job! Your downward block move accuracy is 88.42%.
# Great job! Your downward block move accuracy is 87.89%.
# Great job! Your downward block move accuracy is 87.29%.
# Great job! Your downward block move accuracy is 86.89%.
# Great job! Your downward block move accuracy is 86.53%.
# Great job! Your downward block move accuracy is 86.41%.
# Great job! Your downward block move accuracy is 85.97%.
# Great job! Your downward block move accuracy is 85.61%.
# Great job! Your downward block move accuracy is 85.37%.
# Great job! Your downward block move accuracy is 85.04%.
# Great job! Your downward block move accuracy is 84.65%.
# Great job! Your downward block move accuracy is 84.36%.
# Great job! Your downward block move accuracy is 83.93%.
# Great job! Your downward block move accuracy is 83.56%.
# Great job! Your downward block move accuracy is 83.21%.
# Great job! Your downward block move accuracy is 83.17%.
# Great job! Your downward block move accuracy is 83.13%.
# Great job! Your downward block move accuracy is 83.03%.
# Great job! Your downward block move accuracy is 83.01%.
# Great job! Your downward block move accuracy is 82.99%.
# Great job! Your downward block move accuracy is 83.00%.
# Great job! Your downward block move accuracy is 83.00%.
# Great job! Your downward block move accuracy is 83.07%.
# Great job! Your downward block move accuracy is 83.20%.
# Great job! Your downward block move accuracy is 83.28%.
# Great job! Your downward block move accuracy is 83.12%.
# Great job! Your downward block move accuracy is 82.92%.
# Great job! Your downward block move accuracy is 82.73%.
# Great job! Your downward block move accuracy is 82.76%.
# Great job! Your downward block move accuracy is 82.74%.
# Great job! Your downward block move accuracy is 82.63%.
# Great job! Your downward block move accuracy is 82.48%.
# Great job! Your downward block move accuracy is 82.37%.
# Great job! Your downward block move accuracy is 82.28%.
# Great job! Your downward block move accuracy is 83.01%.
# Great job! Your downward block move accuracy is 83.80%.
# Great job! Your downward block move accuracy is 84.12%.
# Great job! Your downward block move accuracy is 84.06%.
# Great job! Your downward block move accuracy is 84.20%.
# Great job! Your downward block move accuracy is 84.67%.
# Great job! Your downward block move accuracy is 84.45%.
# Great job! Your downward block move accuracy is 84.31%.
# Great job! Your downward block move accuracy is 84.24%.
# Great job! Your downward block move accuracy is 84.18%.
# Great job! Your downward block move accuracy is 84.20%.
# Great job! Your downward block move accuracy is 84.13%.
# Great job! Your downward block move accuracy is 84.07%.
# Great job! Your downward block move accuracy is 84.08%.
# Great job! Your downward block move accuracy is 84.07%.
# Great job! Your downward block move accuracy is 84.08%.
# Great job! Your downward block move accuracy is 84.14%.
# Great job! Your downward block move accuracy is 84.16%.
# Great job! Your downward block move accuracy is 84.17%.
# Great job! Your downward block move accuracy is 84.17%.
# Great job! Your downward block move accuracy is 84.19%.
# Great job! Your downward block move accuracy is 84.19%.
# Great job! Your downward block move accuracy is 84.10%.
# Great job! Your downward block move accuracy is 83.72%.
# Great job! Your downward block move accuracy is 83.30%.
# Great job! Your downward block move accuracy is 82.77%.
# Great job! Your downward block move accuracy is 82.39%.
# Great job! Your downward block move accuracy is 82.37%.
# Great job! Your downward block move accuracy is 82.42%.
# Great job! Your downward block move accuracy is 82.54%.
# Great job! Your downward block move accuracy is 82.68%.
# Great job! Your downward block move accuracy is 83.13%.
# Great job! Your downward block move accuracy is 83.57%.
# Great job! Your downward block move accuracy is 83.97%.
# Great job! Your downward block move accuracy is 84.15%.
# Great job! Your downward block move accuracy is 84.17%.
# Great job! Your downward block move accuracy is 84.09%.
# Great job! Your downward block move accuracy is 84.04%.
# Great job! Your downward block move accuracy is 84.04%.
# Great job! Your downward block move accuracy is 84.05%.
# Great job! Your downward block move accuracy is 84.05%.
# Great job! Your downward block move accuracy is 83.99%.
# Great job! Your downward block move accuracy is 83.99%.
# Great job! Your downward block move accuracy is 84.00%.
# Great job! Your downward block move accuracy is 83.95%.
# Great job! Your downward block move accuracy is 83.99%.
# Great job! Your downward block move accuracy is 84.02%.
# Great job! Your downward block move accuracy is 84.14%.
# Great job! Your downward block move accuracy is 84.35%.
# Great job! Your downward block move accuracy is 84.55%.
# Great job! Your downward block move accuracy is 84.79%.
# Great job! Your downward block move accuracy is 84.94%.
# Great job! Your downward block move accuracy is 85.15%.
# Great job! Your downward block move accuracy is 85.42%.
# Great job! Your downward block move accuracy is 85.69%.
# Great job! Your downward block move accuracy is 86.04%.
# Great job! Your downward block move accuracy is 86.45%.
# Great job! Your downward block move accuracy is 86.69%.
# Great job! Your downward block move accuracy is 87.04%.
# Great job! Your downward block move accuracy is 87.37%.
# Great job! Your downward block move accuracy is 87.60%.
# Great job! Your downward block move accuracy is 87.71%.
# Great job! Your downward block move accuracy is 87.79%.
# Great job! Your downward block move accuracy is 87.89%.
# Great job! Your downward block move accuracy is 87.89%.
# Great job! Your downward block move accuracy is 87.79%.
# Great job! Your downward block move accuracy is 87.61%.
# Great job! Your downward block move accuracy is 87.30%.
# Great job! Your downward block move accuracy is 86.98%.
# Great job! Your downward block move accuracy is 86.57%.
# Great job! Your downward block move accuracy is 86.11%.
# Great job! Your downward block move accuracy is 85.95%.
# Great job! Your downward block move accuracy is 85.92%.
# Great job! Your downward block move accuracy is 85.93%.
# Great job! Your downward block move accuracy is 86.04%.
# Great job! Your downward block move accuracy is 86.32%.
# Great job! Your downward block move accuracy is 86.45%.
# Great job! Your downward block move accuracy is 86.32%.
# Great job! Your downward block move accuracy is 86.40%.
# Great job! Your downward block move accuracy is 86.91%.
# Great job! Your downward block move accuracy is 88.09%.
# Great job! Your downward block move accuracy is 88.54%.
# Great job! Your downward block move accuracy is 89.28%.
# Great job! Your downward block move accuracy is 89.98%.
# Great job! Your downward block move accuracy is 90.67%.
# Great job! Your downward block move accuracy is 90.63%.
# Great job! Your downward block move accuracy is 90.74%.
# Great job! Your downward block move accuracy is 90.04%.
# Great job! Your downward block move accuracy is 90.56%.
# Great job! Your downward block move accuracy is 90.55%.
# Great job! Your downward block move accuracy is 90.33%.
# Great job! Your downward block move accuracy is 89.65%.
# Great job! Your downward block move accuracy is 89.07%.
# Great job! Your downward block move accuracy is 87.57%.
# Great job! Your downward block move accuracy is 86.93%.
# Great job! Your downward block move accuracy is 86.66%.
# Great job! Your downward block move accuracy is 85.99%.
# Great job! Your downward block move accuracy is 85.37%.
# Great job! Your downward block move accuracy is 84.86%.
# Great job! Your downward block move accuracy is 84.13%.
# Great job! Your downward block move accuracy is 83.50%.
# Great job! Your downward block move accuracy is 83.05%.
# Great job! Your downward block move accuracy is 82.71%.
# Great job! Your downward block move accuracy is 82.66%.
# Great job! Your downward block move accuracy is 82.46%.
# Great job! Your downward block move accuracy is 82.48%.
# Great job! Your downward block move accuracy is 82.61%.
# Great job! Your downward block move accuracy is 82.45%.
# Great job! Your downward block move accuracy is 82.92%.
# Great job! Your downward block move accuracy is 83.19%.
# Great job! Your downward block move accuracy is 83.79%.
# Great job! Your downward block move accuracy is 84.11%.
# Great job! Your downward block move accuracy is 84.45%.
# Great job! Your downward block move accuracy is 85.33%.
# Great job! Your downward block move accuracy is 86.12%.
# Great job! Your downward block move accuracy is 86.38%.
# Great job! Your downward block move accuracy is 86.67%.
# Great job! Your downward block move accuracy is 86.93%.
# Great job! Your downward block move accuracy is 87.18%.
# Great job! Your downward block move accuracy is 87.30%.
# Great job! Your downward block move accuracy is 87.55%.
# Great job! Your downward block move accuracy is 87.92%.
# Great job! Your downward block move accuracy is 87.85%.
# Great job! Your downward block move accuracy is 87.89%.
# Great job! Your downward block move accuracy is 87.91%.
# Great job! Your downward block move accuracy is 88.16%.
# Great job! Your downward block move accuracy is 88.33%.
# Great job! Your downward block move accuracy is 88.53%.
# Great job! Your downward block move accuracy is 88.98%.
# Great job! Your downward block move accuracy is 89.78%.
# Great job! Your downward block move accuracy is 91.02%.
# Great job! Your downward block move accuracy is 91.60%.
# Great job! Your downward block move accuracy is 91.34%.
# Great job! Your downward block move accuracy is 91.37%.
# Great job! Your downward block move accuracy is 92.01%.
# Great job! Your downward block move accuracy is 92.74%.
# Great job! Your downward block move accuracy is 92.86%.
# Great job! Your downward block move accuracy is 92.73%.
# Great job! Your downward block move accuracy is 92.76%.
# Great job! Your downward block move accuracy is 92.61%.
# Great job! Your downward block move accuracy is 92.93%.
# Great job! Your downward block move accuracy is 93.24%.
# Great job! Your downward block move accuracy is 93.23%.
# Great job! Your downward block move accuracy is 93.63%.
# Great job! Your downward block move accuracy is 93.68%.
# Great job! Your downward block move accuracy is 93.57%.
# Great job! Your downward block move accuracy is 93.85%.
# Great job! Your downward block move accuracy is 94.11%.
# Great job! Your downward block move accuracy is 93.39%.
# Great job! Your downward block move accuracy is 92.99%.
# Great job! Your downward block move accuracy is 92.58%.
# Great job! Your downward block move accuracy is 91.71%.
# Great job! Your downward block move accuracy is 90.11%.
# Great job! Your downward block move accuracy is 90.41%.
# Great job! Your downward block move accuracy is 89.31%.
# Great job! Your downward block move accuracy is 88.55%.
# Great job! Your downward block move accuracy is 88.17%.
# Great job! Your downward block move accuracy is 88.08%.
# Great job! Your downward block move accuracy is 87.99%.
# Great job! Your downward block move accuracy is 88.09%.
# Great job! Your downward block move accuracy is 89.20%.
# Great job! Your downward block move accuracy is 89.83%.
# Great job! Your downward block move accuracy is 89.29%.
# Great job! Your downward block move accuracy is 88.22%.
# Great job! Your downward block move accuracy is 87.54%.
# Great job! Your downward block move accuracy is 87.68%.
# Great job! Your downward block move accuracy is 87.48%.
# Great job! Your downward block move accuracy is 86.93%.
# Great job! Your downward block move accuracy is 86.43%.
# Great job! Your downward block move accuracy is 86.89%.
# Great job! Your downward block move accuracy is 87.40%.
# Great job! Your downward block move accuracy is 86.25%.
# Great job! Your downward block move accuracy is 85.97%.
# Great job! Your downward block move accuracy is 84.77%.
# Great job! Your downward block move accuracy is 85.42%.
# Great job! Your downward block move accuracy is 85.54%.
# Great job! Your downward block move accuracy is 84.78%.
# Great job! Your downward block move accuracy is 83.86%.
# Keep practicing! Your downward block move accuracy is 79.54%.
# Keep practicing! Your downward block move accuracy is 60.40%.
# Keep practicing! Your downward block move accuracy is 10.25%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# ...
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Keep practicing! Your downward block move accuracy is 0.00%.
# Failed to capture frame. Exiting...
